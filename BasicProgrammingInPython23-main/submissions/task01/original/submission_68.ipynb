# %% [markdown]
# # Coding Tasks - Week 1<a href="#Coding-Tasks---Week-1" class="anchor-link">¶</a>
#
# Welcome to the Python Programming Exercise Sheet!
# In this exercise sheet, we will cover some of the fundamental concepts
# in Python programming.
# Topics covered are: Declaring variables, data types, operations, and
# if-statements.
#
# ------------------------------------------------------------------------
#
# **DEADLINE**: 14th May until 23:59
# **Your name here**: Hardika Potey
# **Your university mail**: hpotey@uos.de \_\_\_
#
# **Important information**:
# In order to pass this sheet you need to achieve 10/20 points.
# For the best possible grade you require 20/20 points, however, since
# some harder tasks may take a lot of time you don't have to pressure
# yourself.
# If you complete any three tasks on a sheet you will definitely get a
# good grade for that sheet.
# Hand in your sheet in studip in the respective folder until the
# deadline.
# If you receive no email until a few days after submission you will have
# passed, the sample solution will also be uploaded around then.
# If you receive an email you don't need to worry, you can fail one sheet
# and also your total points will also be taken into account for the final
# pass or fail.
#
# ## Task 1 Declaring variables (8 points)<a href="#Task-1-Declaring-variables-(8-points)"
# class="anchor-link">¶</a>
#
# Please declare the following variables with the specific data types and
# values listed.
#
# a\) A string with the value "hello world"
# b) An integer with the value "-19"
# c) A float with the value "7.29"
# d) A boolean value of "False"
# e) A tuple containing the integers "1", "2", and the float "4.56"
# f) A list containing the string "a", "b", and "c" as elements
# g) The truth value of 9 is greater than or equal to 9
# h) The result of 28 times 2 minus 14
#
# In \[ \]:
#
#     a = z=str("Hello world")
#     print(type(z))
#     b = x=int("-19")
#     print(type(x))
#     c = y=float("7.29")
#     print(type(y))
#     d = d=bool("False")
#     print(type(d))
#     e = thattuple=("1, 2, 4.56")
#     print(thattuple)
#     f = thislist=("a, b, c")
#     print(thislist)
#     g = j=9
#     print(j >= j)
#     h = k=28
#     m=2
#     l=14
#     print(k*m)-l
#
#     <class 'str'>
#     <class 'int'>
#     <class 'float'>
#     <class 'bool'>
#     1, 2, 4.56
#     a, b, c
#     True
#     56
#
#     ---------------------------------------------------------------------------
#     TypeError                                 Traceback (most recent call last)
#     Cell In[4], line 18
#          16 m=2
#          17 l=14
#     ---> 18 print(k*m)-l
#
#     TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'
#
# ## Task 2 Implementing formulas (4 points)<a href="#Task-2-Implementing-formulas-(4-points)"
# class="anchor-link">¶</a>
#
# Please implement mathematical formulas in the cells below.
# You are given four variables `a` `b` `c`, and `d` at the start, and can
# chose any float or integer value for them to test your formula.
# Note however that, depending on what you chose, you may run into
# division by zero errors or a negative squareroot, so chose carefully if
# you wish to change these.
#
# In \[ \]:
#
#     a = 1
#     b = 2
#     c = 5.37 (5)
#     d = 7.92 (7)
#     c=int(5.37)
#     print(c)
#     d=int(7.92)
#     print(d)
#
#     5
#     7
#
# ### Formula 1<a href="#Formula-1" class="anchor-link">¶</a>
#
# \$\frac{A+B}{C+D}\$
# "A plus B divided by C plus D"
#
# In \[ \]:
#
#     a=1
#     b=2
#     c=5
#     d=7
#     antworten=(a+b)/(c+d)
#     print(antworten)
#
#     0.25
#
# ## Formula 2<a href="#Formula-2" class="anchor-link">¶</a>
#
# \$\frac{A+B+C+D}{4}\$
# "The sum of A, B, C, and D, divided by four"
#
# In \[ \]:
#
#     a=1
#     b=2
#     c=5
#     d=7
#     sol=(a+b+c+d)/4
#     print(sol)
#
#     3.75
#
# ### Formula 3<a href="#Formula-3" class="anchor-link">¶</a>
#
# \$\frac{A^2+B^3}{1+\frac{C}{D}}\$
# "A to the power of 2 plus B to the power of 3, divided by 1 plus the
# quotient of C and D"
#
# In \[ \]:
#
#     a=1
#     b=2
#     c=5
#     d=7
#     math=(a**2)+(b**3) / (1 + (c  /d))
#     print(math)
#
#     5.666666666666666
#
# ### Formula 4<a href="#Formula-4" class="anchor-link">¶</a>
#
# \$\sqrt\[2\]{A-B}\$
# "The square root of A minus B"
# **Hint:** You can use the power of 1/2 instead here.
#
# In \[ \]:
#
#     a=1
#     b=2
#     c=5
#     d=7
#     wow=(a-b)**1/2
#     print(wow)
#
#     -0.5
#
# ## Task 3 Variables - Value Switching (3 points)<a href="#Task-3-Variables---Value-Switching-(3-points)"
# class="anchor-link">¶</a>
#
# Write a program that asks the user to enter two different numbers and
# then switches the values that are stored in a and b. Print the switched
# values as an output.
#
# **Hint:** You may need to look up `input()` function to gather
# information from the users.
#
# In \[ \]:
#
#     a = input("3")
#     b = input("4")
#     print("Original Values:")
#     print("a=", a)
#     print("b=", b)
#
#     Original Values:
#     a= 3
#     b= 4
#
# In \[ \]:
#
#     temp=a
#     a=b
#     b=temp
#     print("Switched Values:")
#     print("a=", a)
#     print("b=", b)
#     print(a,b)
#
#     Switched Values:
#     a= 4
#     b= 3
#     4 3
#
# ## Task 4 If statements (5 points)<a href="#Task-4-If-statements-(5-points)" class="anchor-link">¶</a>
#
# Imagine that you are working at a theme park and selling tickets for the
# rollercoaster.
# You are obliged to ask all visitors about their height (in cm) before
# selling them any tickets.
# If they are 120cm or taller than that, then they are allowed to ride the
# rollercoaster and you need to ask how old they are.
# Depending on their age, the amount that they have to pay differs:
#
# -   If they are younger than 12: 5€
# -   If they are 18 or younger: 8€
# -   If they are older than 18: 15€
#
# Depending on the result change the value of the variables price (int)
# and allowed (bool) to match the specified conditions!
#
# **Hint:** Do not forget to inform the visitors shorter than 120cm that
# they cannot ride the rollercoaster at the moment.
# You can adjust the code in the cell below to or use the input statement
# which is commented out to test for specific height and age
# combinations.
# If someone is not allowed on the ride, then you do not need to give them
# a price obviously.
#
# In \[ \]:
#
#     height
#     age =
#
#     allowed = True
#     price =
#
#     #alternatively comment this out and input
#     # print("Height:")
#     # height = int(input())
#     # age = int(input())
#
#     height= int(input(""))
#     age = int(input(""))
#
# In \[ \]:
#
#     height = int(input("125"))
#
#     if height >= 120:
#         age = int(input("10"))
#
#         if age < 12:
#             price = 5
#         elif age <= 18:
#             price = 8
#         else:
#             price = 15
#
#         allowed = True
#         print("You are allowed to ride the rollercoaster!")
#         print("Ticket price: €", price)
#     else:
#         allowed = False
#         print("Sorry, you cannot ride the rollercoaster.")
#
#     print("Allowed:", allowed)
#
#     You are allowed to ride the rollercoaster!
#     Ticket price: € 5
#     Allowed: True
#
# In \[ \]:
#
#     height = int(input("94"))
#
#     if height >= 120:
#         age = int(input("7"))
#
#         if age < 12:
#             price = 5
#         elif age <= 18:
#             price = 8
#         else:
#             price = 15
#
#         allowed = True
#         print("You are allowed to ride the rollercoaster!")
#         print("Ticket price: €", price)
#     else:
#         allowed = False
#         print("Sorry, you cannot ride the rollercoaster.")
#
#     print("Allowed:", allowed)
#
#     Sorry, you cannot ride the rollercoaster.
#     Allowed: False
#
# In \[ \]:
#
#     height = int(input("189"))
#
#     if height >= 120:
#         age = int(input("17"))
#
#         if age < 12:
#             price = 5
#         elif age <= 18:
#             price = 8
#         else:
#             price = 15
#
#         allowed = True
#         print("You are allowed to ride the rollercoaster!")
#         print("Ticket price: €", price)
#     else:
#         allowed = False
#         print("Sorry, cannot ride the rollercoaster.")
#
#     print("Allowed:", allowed)
#
#     You are allowed to ride the rollercoaster!
#     Ticket price: € 8
#     Allowed: True
#
# In \[ \]:
#
#     height = int(input("167"))
#
#     if height >= 120:
#         age = int(input("21"))
#
#         if age < 12:
#             price = 5
#         elif age <= 18:
#             price = 8
#         else:
#             price = 15
#
#         allowed = True
#         print("You are allowed to ride the rollercoaster!")
#         print("Ticket price: €", price)
#     else:
#         allowed = False
#         print("Sorry, you cannot ride the rollercoaster.")
#
#     print("Allowed:", allowed)
#
#     You are allowed to ride the rollercoaster!
#     Ticket price: € 15
#     Allowed: True
